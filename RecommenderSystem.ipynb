# %% [markdown]
# # Movie Recommender System

# %% [markdown]
# Here I use the data from movielens which is a site dedicated to collect over thousands of movie ratings from the user. I first download the data from its website
# ============================
# MovieLens 100K Dataset
#
# Stable benchmark dataset. 100,000 ratings from 1000 users on 1700 movies. Released 4/1998.
#
# README.txt
# ml-100k.zip (size: 5 MB, checksum)
# Index of unzipped files
# Permalink: http://grouplens.org/datasets/movielens/100k/
# =============================

# %%
import pandas as pd
import numpy as np

col_name_1 = ['user_id', 'movie_id', 'rating']
col_name_2 = ['movie_id', 'title']

ratings = pd.read_csv('/Users/baileyhsu/Desktop/ml-100k/u.data', sep='\t', names=col_name_1, usecols=range(3), encoding="ISO-8859-1")
movieid = pd.read_csv('/Users/baileyhsu/Desktop/ml-100k/u.item', sep='|', names=col_name_2, usecols=range(2), encoding="ISO-8859-1")

temp = pd.merge(movieid, ratings)

# %% [markdown]
# Next, we will need to create a pivot table to have the user_id in the row, and movie name in the column, and the rating number as the value of each grid.

# %%
Ratings = temp.pivot_table(index=['user_id'],columns=['title'],values='rating')
Ratings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
# 5                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# 1                                        3.0                           4.0
# 2                                        NaN                           NaN
# 3                                        NaN                           NaN
# 4                                        NaN                           NaN
# 5                                        NaN                           4.0
#
# title    3 Ninjas: High Noon At Mega Mountain (1998)  39 Steps, The (1935)  \
# user_id
# 1                                                NaN                   NaN
# 2                                                1.0                   NaN
# 3                                                NaN                   NaN
# 4                                                NaN                   NaN
# 5                                                NaN                   NaN
#
# title                   ...                  Yankee Zulu (1994)  \
# user_id                 ...
# 1                       ...                                 NaN
# 2                       ...                                 NaN
# 3                       ...                                 NaN
# 4                       ...                                 NaN
# 5                       ...                                 NaN
#
# title    Year of the Horse (1997)  You So Crazy (1994)  \
# user_id
# 1                             NaN                  NaN
# 2                             NaN                  NaN
# 3                             NaN                  NaN
# 4                             NaN                  NaN
# 5                             NaN                  NaN
#
# title    Young Frankenstein (1974)  Young Guns (1988)  Young Guns II (1990)  \
# user_id
# 1                              5.0                3.0                   NaN
# 2                              NaN                NaN                   NaN
# 3                              NaN                NaN                   NaN
# 4                              NaN                NaN                   NaN
# 5                              4.0                NaN                   NaN
#
# title    Young Poisoner's Handbook, The (1995)  Zeus and Roxanne (1997)  \
# user_id
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
# 5                                          NaN                      NaN
#
# title    unknown  Á köldum klaka (Cold Fever) (1994)
# user_id
# 1            4.0                                 NaN
# 2            NaN                                 NaN
# 3            NaN                                 NaN
# 4            NaN                                 NaN
# 5            4.0                                 NaN
#
# [5 rows x 1664 columns]

# %% [markdown]
# For example, below we can find the correlations of all the movies with respect to the Indiana Johns based on the rating

# %%
indianaRating=Ratings['Indiana Jones and the Last Crusade (1989)']
corrIndiana = Ratings.corrwith(indianaRating)

#drop NAN term
corrIndiana = corrIndiana.dropna()

#convert it to pd data frame
df = pd.DataFrame(corrIndiana)

#sort it 
corrIndiana.sort_values(ascending=False)
# Out:
# title
# 'Til There Was You (1997)                             1.0
# Crossfire (1947)                                      1.0
# My Favorite Season (1993)                             1.0
# Wild Reeds (1994)                                     1.0
# Metisse (Café au Lait) (1993)                         1.0
# Maya Lin: A Strong Clear Vision (1994)                1.0
# Second Jungle Book: Mowgli & Baloo, The (1997)        1.0
# Colonel Chabert, Le (1994)                            1.0
# Infinity (1996)                                       1.0
# Indiana Jones and the Last Crusade (1989)             1.0
# Cement Garden, The (1993)                             1.0
# Dangerous Ground (1997)                               1.0
# Stripes (1981)                                        1.0
# Faces (1968)                                          1.0
# Vermin (1998)                                         1.0
# Forbidden Christ, The (Cristo proibito, Il) (1950)    1.0
# Bad Moon (1996)                                       1.0
# Wedding Gift, The (1994)                              1.0
# Beans of Egypt, Maine, The (1994)                     1.0
# Gabbeh (1996)                                         1.0
# Safe Passage (1994)                                   1.0
# Hurricane Streets (1998)                              1.0
# Bewegte Mann, Der (1994)                              1.0
# Scarlet Letter, The (1926)                            1.0
# Manny & Lo (1996)                                     1.0
# Guantanamera (1994)                                   1.0
# Newton Boys, The (1998)                               1.0
# Ed (1996)                                             1.0
# Dream With the Fishes (1997)                          1.0
# Anna (1996)                                           1.0
#                                                      ...
# Four Days in September (1997)                        -1.0
# Best Men (1997)                                      -1.0
# Nosferatu a Venezia (1986)                           -1.0
# Talking About Sex (1994)                             -1.0
# Joy Luck Club, The (1993)                            -1.0
# Stars Fell on Henrietta, The (1995)                  -1.0
# Last Time I Committed Suicide, The (1997)            -1.0
# Roseanna's Grave (For Roseanna) (1997)               -1.0
# Schizopolis (1996)                                   -1.0
# Glass Shield, The (1994)                             -1.0
# Fille seule, La (A Single Girl) (1995)               -1.0
# Phat Beach (1996)                                    -1.0
# Broken English (1996)                                -1.0
# Duoluo tianshi (1995)                                -1.0
# Slingshot, The (1993)                                -1.0
# Magic Hour, The (1998)                               -1.0
# Collectionneuse, La (1967)                           -1.0
# Good Man in Africa, A (1994)                         -1.0
# Show, The (1995)                                     -1.0
# Lover's Knot (1996)                                  -1.0
# Tough and Deadly (1995)                              -1.0
# The Innocent (1994)                                  -1.0
# 1-900 (1994)                                         -1.0
# American Dream (1990)                                -1.0
# Female Perversions (1996)                            -1.0
# Theodore Rex (1995)                                  -1.0
# Ponette (1996)                                       -1.0
# Search for One-eye Jimmy, The (1996)                 -1.0
# Spirits of the Dead (Tre passi nel delirio) (1968)   -1.0
# Incognito (1997)                                     -1.0
# dtype: float64

# %% [markdown]
# However, the above result seems strange probably due to the low rating size of some movies. Therefore, we start again to collect the rating size and the mean of the origin data

# %%
# we can group by the movie title with columns set to be the size and the mean of the rating value
movies = temp.groupby('title').agg({'rating':[np.size, np.mean]})

# here we define the hot movies as size of the ratings larger than 50
hotmovies = movies['rating']['size'] >= 100

# plugged back to the origin movies data set, we can find the top 30 rated popular movies
movies[hotmovies].sort_values([('rating', 'mean')])[:30]
# Out:
#                                        rating
#                                          size      mean
# title
# Cable Guy, The (1996)                     106  2.339623
# Jungle2Jungle (1997)                      132  2.439394
# Crash (1996)                              128  2.546875
# Event Horizon (1997)                      127  2.574803
# Spawn (1997)                              143  2.615385
# Batman Forever (1995)                     114  2.666667
# Batman Returns (1992)                     142  2.683099
# George of the Jungle (1997)               162  2.685185
# Down Periscope (1996)                     101  2.702970
# Mimic (1997)                              101  2.742574
# Beavis and Butt-head Do America (1996)    156  2.788462
# Waterworld (1995)                         102  2.803922
# Volcano (1997)                            219  2.808219
# Alien 3 (1992)                            100  2.830000
# Multiplicity (1996)                       134  2.835821
# Mars Attacks! (1996)                      217  2.847926
# Father of the Bride Part II (1995)        128  2.898438
# 101 Dalmatians (1996)                     109  2.908257
# Nutty Professor, The (1996)               163  2.914110
# Dante's Peak (1997)                       240  2.933333
# Lost World: Jurassic Park, The (1997)     158  2.943038
# Natural Born Killers (1994)               128  2.953125
# Evita (1996)                              259  2.980695
# Net, The (1995)                           120  3.008333
# First Wives Club, The (1996)              160  3.018750
# Broken Arrow (1996)                       254  3.031496
# Star Trek: The Motion Picture (1979)      117  3.034188
# Grumpier Old Men (1995)                   148  3.040541
# Conan the Barbarian (1981)                107  3.046729
# Ace Ventura: Pet Detective (1994)         103  3.048544

# %%
df = movies[hotmovies].join(pd.DataFrame(corrIndiana, columns=['Similarity']))
df.sort_values(['Similarity'], ascending=False)[:15]
# Out:
#                                            (rating, size)  (rating, mean)  \
# title
# Indiana Jones and the Last Crusade (1989)             331        3.930514
# Ghost and the Darkness, The (1996)                    128        3.203125
# Raiders of the Lost Ark (1981)                        420        4.252381
# Young Guns (1988)                                     101        3.207921
# Back to the Future (1985)                             350        3.834286
# Firm, The (1993)                                      151        3.278146
# Donnie Brasco (1997)                                  147        3.802721
# Waterworld (1995)                                     102        2.803922
# Independence Day (ID4) (1996)                         429        3.438228
# Lost World: Jurassic Park, The (1997)                 158        2.943038
# Frighteners, The (1996)                               115        3.234783
# Abyss, The (1989)                                     151        3.589404
# Nutty Professor, The (1996)                           163        2.914110
# Star Trek: Generations (1994)                         116        3.336207
# While You Were Sleeping (1995)                        162        3.549383
#
#                                            Similarity
# title
# Indiana Jones and the Last Crusade (1989)    1.000000
# Ghost and the Darkness, The (1996)           0.553154
# Raiders of the Lost Ark (1981)               0.539606
# Young Guns (1988)                            0.492670
# Back to the Future (1985)                    0.479793
# Firm, The (1993)                             0.477194
# Donnie Brasco (1997)                         0.469901
# Waterworld (1995)                            0.465230
# Independence Day (ID4) (1996)                0.461999
# Lost World: Jurassic Park, The (1997)        0.452847
# Frighteners, The (1996)                      0.447761
# Abyss, The (1989)                            0.442896
# Nutty Professor, The (1996)                  0.441281
# Star Trek: Generations (1994)                0.427968
# While You Were Sleeping (1995)               0.423701

# %% [markdown]
# Now we see the top 15 movies actually look more than people who would watch Indiana Jones would watch too!
#
#
# What else can we improve? Maybe increased the threshold of the rating size?

# %%
# here we define the hot movies as size of the ratings larger than 50
hotmovies = movies['rating']['size'] >= 200

# %%
df = movies[hotmovies].join(pd.DataFrame(corrIndiana, columns=['Similarity']))
df.sort_values(['Similarity'], ascending=False)[:15]
# Out:
#                                            (rating, size)  (rating, mean)  \
# title
# Indiana Jones and the Last Crusade (1989)             331        3.930514
# Raiders of the Lost Ark (1981)                        420        4.252381
# Back to the Future (1985)                             350        3.834286
# Independence Day (ID4) (1996)                         429        3.438228
# Return of the Jedi (1983)                             507        4.007890
# Liar Liar (1997)                                      485        3.156701
# Jurassic Park (1993)                                  261        3.720307
# Fugitive, The (1993)                                  336        4.044643
# Speed (1994)                                          230        3.647826
# Terminator 2: Judgment Day (1991)                     295        4.006780
# Eraser (1996)                                         206        3.150485
# True Lies (1994)                                      208        3.562500
# Apollo 13 (1995)                                      276        3.931159
# Mission: Impossible (1996)                            344        3.313953
# Hunt for Red October, The (1990)                      227        3.863436
#
#                                            Similarity
# title
# Indiana Jones and the Last Crusade (1989)    1.000000
# Raiders of the Lost Ark (1981)               0.539606
# Back to the Future (1985)                    0.479793
# Independence Day (ID4) (1996)                0.461999
# Return of the Jedi (1983)                    0.422294
# Liar Liar (1997)                             0.414427
# Jurassic Park (1993)                         0.399337
# Fugitive, The (1993)                         0.395868
# Speed (1994)                                 0.381742
# Terminator 2: Judgment Day (1991)            0.367973
# Eraser (1996)                                0.366153
# True Lies (1994)                             0.362574
# Apollo 13 (1995)                             0.357360
# Mission: Impossible (1996)                   0.356357
# Hunt for Red October, The (1990)             0.355798
